# %%
# !python --version
# Out:
# Python 3.7.9

# %% [markdown]
# # 3.7.9 입장 방법
#
# 1. anaconda prompt 진입
# 2. activate py37
# 3. jupyter notebook

# %% [markdown]
# !pip install tensorflow

# %% [markdown]
# !pip list

# %% [markdown]
# # 일반적인 선형회귀 가정

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# # 선형회귀를 가정한다
# - np.sum((beta[0] + beta[1]*x - y)**2) array 타입의 경우 최소제곱법 추정
# - np.mean((beta[0] + beta[1]*x - y)**2) MSE 처리시
# - 리스트로 처리할 경우 루프처리

# %%
x = [1,2,3,4]
y = [0,-1,-3,-3]

# %% [markdown]
# # 1. 손실함수 정의

# %%
def mse(beta,x,y):
    n = len(x)
    val = 0.0
    
    for i in range(n):
        # np.sum((beta[0] + beta[1]*x - y)**2) array 타입의 경우 최소제곱법 추정
        # np.mean((beta[0] + beta[1]*x - y)**2) MSE 처리시 
        # 리스트로 처리할 경우 루프처리 
        val += (beta[0] + beta[1]*x[i] - y[i])**2 / n
    return val

# %% [markdown]
# # 2. 기울기 함수도 가정해보자
# - val += (beta[0] + beta[1]* x[i] - y[i])**2 / n 를 미분해서
# - val += 2 * error * np.array([x[i], 1])/n 만들었다

# %%
def grad_loss(beta,x,y):
    dim = len(beta)
    n = len(x)
    val = np.array([0.0,0.0])
    for i in range(n):
        error = beta[0] + beta[1]*x[i] - y[i]
        val += 2.0*error * np.array([1.0, x[i]]) / n
    return val

# %% [markdown]
# # 3. 최적화 과정(Gradient Descent)
# - 기본적으로 0.01

# %%
maxIter = 100
learning_rate = 0.01
beta0 = np.array([0,0])

for i in range(maxIter):
    grad = grad_loss(beta0, x , y)
    beta1 = beta0 - learning_rate * grad
    beta0 = beta1 
    print(beta0, loss(beta0, x, y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-524f4edb9d42> in <module>
#       7     beta1 = beta0 - learning_rate * grad
#       8     beta0 = beta1
# ----> 9     print(beta0, loss(beta0, x, y))
#
# TypeError: 'tensorflow.python.framework.ops.EagerTensor' object is not callable

# %% [markdown]
# # 2. 텐서 플로우를 이용한 선형회귀

# %% [markdown]
# ## 2.1 텐서플로우의 변수
# - Constant (상수)
# - Variable (가변값)

# %% [markdown]
# ### 초기값 지정
# - beta = tf.Variable([0,0], dtype=float64) 이렇게 지정할 수도 있음
# - 위에서 지정한 x와 y값을 그대로 이용하겠다
# - 은 아니고 constant 지정하겠다

# %%
x = tf.constant([1,2,3,4], dtype=tf.float64)
y = tf.constant([0,-1,-3,-3], dtype=tf.float64)

# %%
a = tf.Variable([0], dtype=tf.float64) # 기울기 x에 대한, beta1, w1, 변수의 영향력(회귀계수)
b = tf.Variable([0], dtype=tf.float64) # y절편, beta0, bias(편향)

beta = tf.Variable([0,0])

# %% [markdown]
# # 2.2 손실함수와 최적화 함수 정의
# - 리니어모델 , 손실함수

# %%
def linear_model(x):
    return b + a*x 


def mse(yhat, y):
    return tf.reduce_sum(tf.pow(yhat-y,2)) / ( x.shape[0]) #*2 

optimizer = tf.optimizers.SGD(0.01)

# %% [markdown]
# # 2.3 최적화 과정 정의

# %%
def optimization():
    #  주어진 입력변수에 대해서 자동으로 기울기를 구해준다. 
    with tf.GradientTape() as grad: 
        yhat = linear_model(x)
        loss = mse(yhat,y)
        
        
    # 기울기 계산 
    gradients = grad.gradient( loss, [ a , b ] )
    
    # a,b 업데이트 
    optimizer.apply_gradients( zip( gradients, [ a, b ] ) )

# %% [markdown]
# - beta0 = b
# - beta1 = 기울기

# %% [markdown]
# # 2.4 학습(training)

# %%
maxIter = 1000
for i in range(maxIter):
    optimization()
    yhat = linear_model(x)
    loss = mse(yhat, y)
    print('step : {}, loss: {}, a: {}, b; {}'.format(i, loss, a, b))
# Out:
# step : 0, loss: 3.425537526909821, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.115])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.035])>
# step : 1, loss: 2.5060663898646043, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.211])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.06355])>
# step : 2, loss: 1.8676128927953963, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.29117249])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.086729])>
# step : 3, loss: 1.4241542940276417, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.35816017])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.10543579])>
# step : 4, loss: 1.116001216503328, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.41416435])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.12041907])>
# step : 5, loss: 0.9017364479676788, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.46101875])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.13230247])>
# step : 6, loss: 0.7526214449278392, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.50025081])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.14160548])>
# step : 7, loss: 0.6487151240623148, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.53313291])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.14876083])>
# step : 8, loss: 0.5761807736743624, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.56072493])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.15412897])>
# step : 9, loss: 0.525417376512874, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.58390974])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.15801014])>
# step : 10, loss: 0.48976297420330495, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.60342278])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16065445])>
# step : 11, loss: 0.46459495925204314, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.61987664])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16227023])>
# step : 12, loss: 0.44670578669821903, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.63378163])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16303099])>
# step : 13, loss: 0.43386979363323075, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.64556283])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16308129])>
# step : 14, loss: 0.4245426244273834, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.65557435])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16254152])>
# step : 15, loss: 0.4176526682518338, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.66411112])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16151197])>
# step : 16, loss: 0.41245634198601905, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.67141885])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.16007618])>
# step : 17, loss: 0.40843767408762255, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.67770221])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.15830371])>
# step : 18, loss: 0.4052386279633964, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.6831317])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.15625253])>
# step : 19, loss: 0.40261075482943587, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.68784932])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.15397089])>
# step : 20, loss: 0.40038164665302667, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.69197337])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.15149901])>
# step : 21, loss: 0.39843165855804863, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.69560242])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.14887036])>
# step : 22, loss: 0.396677756993926, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.69881854])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.14611283])>
# step : 23, loss: 0.39506231232118316, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.70169011])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.14324965])>
# step : 24, loss: 0.39354532222310085, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.70427411])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.14030015])>
# step : 25, loss: 0.3920990156950389, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.70661799])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.13728044])>
# step : 26, loss: 0.390704108866252, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.70876127])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.13420393])>
# step : 27, loss: 0.389347206993333, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.71073688])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.13108179])>
# step : 28, loss: 0.3880190017579115, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.71257226])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.12792331])>
# step : 29, loss: 0.38671302040915356, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.71429026])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.12473623])>
# step : 30, loss: 0.38542475781970137, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.71590991])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.12152699])>
# step : 31, loss: 0.3841510742371499, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.71744707])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.11830096])>
# step : 32, loss: 0.3828897773960417, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.71891496])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.11506259])>
# step : 33, loss: 0.3816393325537285, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72032459])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.11181559])>
# step : 34, loss: 0.38039866128990063, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72168512])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.10856305])>
# step : 35, loss: 0.37916700189735, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7230042])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.10530753])>
# step : 36, loss: 0.3779438125095917, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72428819])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.10205117])>
# step : 37, loss: 0.37672870388269103, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72554241])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.09879574])>
# step : 38, loss: 0.37552139275351737, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72677126])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.0955427])>
# step : 39, loss: 0.3743216694755493, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72797843])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.09229328])>
# step : 40, loss: 0.37312937556157333, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.72916701])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.0890485])>
# step : 41, loss: 0.37194438810057073, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73033953])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.08580918])>
# step : 42, loss: 0.370766608944458, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73149814])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.08257602])>
# step : 43, loss: 0.3695959572045331, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73264462])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.07934959])>
# step : 44, loss: 0.3684323640444572, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73378045])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.07613037])>
# step : 45, loss: 0.3672757690667604, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73490686])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.07291874])>
# step : 46, loss: 0.3661261178050566, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7360249])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.06971502])>
# step : 47, loss: 0.3649833599834962, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73713541])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.06651947])>
# step : 48, loss: 0.3638474483085867, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73823913])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.06333231])>
# step : 49, loss: 0.3627183376304153, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.73933664])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.06015371])>
# step : 50, loss: 0.3615959843601975, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74042846])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.0569838])>
# step : 51, loss: 0.3604803460656848, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.741515])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.05382271])>
# step : 52, loss: 0.3593713811899872, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74259661])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.0506705])>
# step : 53, loss: 0.35826904885603666, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7436736])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.04752726])>
# step : 54, loss: 0.35717330873047315, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74474619])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.04439304])>
# step : 55, loss: 0.3560841209287694, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74581461])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.04126787])>
# step : 56, loss: 0.3550014459489695, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74687903])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.03815178])>
# step : 57, loss: 0.3539252446252875, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74793959])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.03504479])>
# step : 58, loss: 0.3528554780954876, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.74899641])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.03194692])>
# step : 59, loss: 0.3517921077778289, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7500496])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.02885816])>
# step : 60, loss: 0.3507350953546501, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75109925])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.02577851])>
# step : 61, loss: 0.3496844027605659, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75214544])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.02270798])>
# step : 62, loss: 0.3486399921738606, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75318822])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.01964655])>
# step : 63, loss: 0.3476018260101098, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75422766])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.01659421])>
# step : 64, loss: 0.34656986691734354, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7552638])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.01355094])>
# step : 65, loss: 0.34554407777228746, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75629669])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.01051673])>
# step : 66, loss: 0.3445244216773492, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75732635])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.00749156])>
# step : 67, loss: 0.34351086195812874, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75835282])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.00447541])>
# step : 68, loss: 0.3425033621612916, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.75937612])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.00146827])>
# step : 69, loss: 0.3415018860526973, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76039629])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.00152991])>
# step : 70, loss: 0.3405063976157082, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76141334])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.00451912])>
# step : 71, loss: 0.33951686104962375, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7624273])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.00749941])>
# step : 72, loss: 0.3385332407682068, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76343817])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.01047078])>
# step : 73, loss: 0.33755550139827284, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76444599])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.01343328])>
# step : 74, loss: 0.33658360777832885, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76545075])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.01638691])>
# step : 75, loss: 0.33561752495724556, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76645248])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.01933171])>
# step : 76, loss: 0.33465721819295735, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7674512])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.0222677])>
# step : 77, loss: 0.33370265295118334, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.7684469])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.02519491])>
# step : 78, loss: 0.33275379490416385, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.76943961])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.02811335])>
# step : 79, loss: 0.33181060992941097, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.77042934])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.03102307])>
# step : 80, loss: 0.33087306410847334, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.77141609])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0
a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85137621])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.26901573])>
# step : 174, loss: 0.26370746499276054, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85212056])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.27120422])>
# step : 175, loss: 0.26317709709798437, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85286269])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.27338617])>
# step : 176, loss: 0.26264990018891743, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85360259])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.27556158])>
# step : 177, loss: 0.26212585530673826, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85434028])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.27773048])>
# step : 178, loss: 0.2616049436059769, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85507576])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.27989288])>
# step : 179, loss: 0.2610871463538374, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85580904])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.28204881])>
# step : 180, loss: 0.2605724449295243, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85654013])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.28419829])>
# step : 181, loss: 0.26006082082357307, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85726902])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.28634133])>
# step : 182, loss: 0.259552255637184, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85799574])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.28847795])>
# step : 183, loss: 0.25904673108156145, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85872027])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.29060818])>
# step : 184, loss: 0.25854422897725504, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.85944264])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.29273203])>
# step : 185, loss: 0.25804473125350685, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86016285])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.29484952])>
# step : 186, loss: 0.25754821994760063, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.8608809])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.29696067])>
# step : 187, loss: 0.257054677204217, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86159679])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.2990655])>
# step : 188, loss: 0.25656408527479035, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86231055])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.30116403])>
# step : 189, loss: 0.25607642651687107, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86302217])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.30325628])>
# step : 190, loss: 0.2555916833934909, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86373166])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.30534226])>
# step : 191, loss: 0.25510983847253227, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86443902])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.307422])>
# step : 192, loss: 0.25463087442610166, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86514427])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.30949551])>
# step : 193, loss: 0.25415477402990594, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.8658474])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.31156281])>
# step : 194, loss: 0.253681520162634, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86654843])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.31362393])>
# step : 195, loss: 0.25321109580533924, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86724737])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.31567887])>
# step : 196, loss: 0.2527434840408299, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.8679442])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.31772766])>
# step : 197, loss: 0.2522786680530586, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86863896])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.31977032])>
# step : 198, loss: 0.2518166311265187, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.86933163])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.32180686])>
# step : 199, loss: 0.2513573566456426, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87002223])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.32383731])>
# step : 200, loss: 0.2509008280942052, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87071076])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.32586167])>
# step : 201, loss: 0.2504470290547288, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87139723])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.32787997])>
# step : 202, loss: 0.24999594320789362, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87208164])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.32989224])>
# step : 203, loss: 0.24954755433194975, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87276401])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.33189847])>
# step : 204, loss: 0.24910184630213542, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87344433])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.33389871])>
# step : 205, loss: 0.2486588030900957, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87412262])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.33589295])>
# step : 206, loss: 0.2482184087633069, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87479887])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.33788122])>
# step : 207, loss: 0.24778064748450318, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.8754731])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.33986354])>
# step : 208, loss: 0.24734550351110762, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87614531])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.34183992])>
# step : 209, loss: 0.2469129611946651, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87681551])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.34381039])>
# step : 210, loss: 0.24648300498028047, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87748371])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.34577496])>
# step : 211, loss: 0.24605561940605897, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.8781499])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.34773364])>
# step : 212, loss: 0.24563078910254976, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.87881409])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.34968647])>
# step : 213, loss: 0.2452084987921936, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.8794763])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.35163344])>
# step : 214, loss: 0.2447887332887734, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.88013653])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.35357459])>
# step : 215, loss: 0.24437147749686805, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.88079478])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.35550992])>
# step : 216, loss: 0.24395671641130967, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.88145106])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.35743946])>
# step : 217, loss: 0.2435444351166438, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.88210537])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.35936323])>
# step : 218, loss: 0.2431346187865931, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.88275773])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.36128123])>
# step : 219, loss: 0.24272725268352413, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-0.88340813])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0
>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.92949771])>
# step : 954, loss: 0.17582518350467014, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07609242])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.92970879])>
# step : 955, loss: 0.17582024986308528, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07616399])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.92991923])>
# step : 956, loss: 0.17581534571896268, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07623536])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93012905])>
# step : 957, loss: 0.1758104708959417, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.0763065])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93033823])>
# step : 958, loss: 0.17580562521871607, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07637744])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.9305468])>
# step : 959, loss: 0.17580080851302765, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07644816])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93075473])>
# step : 960, loss: 0.1757960206056603, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07651868])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93096205])>
# step : 961, loss: 0.17579126132443346, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07658898])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93116874])>
# step : 962, loss: 0.17578653049819606, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07665907])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93137481])>
# step : 963, loss: 0.17578182795681974, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07672895])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93158027])>
# step : 964, loss: 0.17577715353119436, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07679862])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93178511])>
# step : 965, loss: 0.17577250705321984, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07686808])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93198934])>
# step : 966, loss: 0.17576788835580187, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07693734])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93219296])>
# step : 967, loss: 0.1757632972728449, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07700638])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93239596])>
# step : 968, loss: 0.17575873363924616, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07707522])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93259836])>
# step : 969, loss: 0.17575419729089078, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07714386])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93280016])>
# step : 970, loss: 0.17574968806464417, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07721229])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93300135])>
# step : 971, loss: 0.1757452057983476, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07728051])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93320194])>
# step : 972, loss: 0.17574075033081207, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07734853])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93340192])>
# step : 973, loss: 0.1757363215018116, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07741635])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93360131])>
# step : 974, loss: 0.17573191915207903, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07748396])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.9338001])>
# step : 975, loss: 0.1757275431232987, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07755137])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.9339983])>
# step : 976, loss: 0.175723193258102, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07761858])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.9341959])>
# step : 977, loss: 0.17571886940006082, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07768559])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93439291])>
# step : 978, loss: 0.17571457139368268, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.0777524])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93458933])>
# step : 979, loss: 0.17571029908440453, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.077819])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93478517])>
# step : 980, loss: 0.1757060523185872, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07788541])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93498041])>
# step : 981, loss: 0.17570183094351083, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07795162])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93517508])>
# step : 982, loss: 0.17569763480736797, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07801763])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93536916])>
# step : 983, loss: 0.17569346375925912, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07808344])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93556265])>
# step : 984, loss: 0.17568931764918683, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07814906])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93575557])>
# step : 985, loss: 0.17568519632805024, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07821448])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93594791])>
# step : 986, loss: 0.17568109964764086, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.0782797])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93613968])>
# step : 987, loss: 0.17567702746063518, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07834473])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93633087])>
# step : 988, loss: 0.17567297962059106, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07840957])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93652149])>
# step : 989, loss: 0.17566895598194204, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07847421])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93671154])>
# step : 990, loss: 0.17566495639999175, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07853865])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93690102])>
# step : 991, loss: 0.1756609807309089, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.0786029])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93708993])>
# step : 992, loss: 0.17565702883172246, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07866697])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93727828])>
# step : 993, loss: 0.17565310056031588, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07873083])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93746606])>
# step : 994, loss: 0.17564919577542232, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07879451])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93765328])>
# step : 995, loss: 0.17564531433661962, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.078858])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93783994])>
# step : 996, loss: 0.17564145610432536, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.0789213])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93802604])>
# step : 997, loss: 0.17563762093979118, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.0789844])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93821159])>
# step : 998, loss: 0.1756338087050991, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07904732])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93839657])>
# step : 999, loss: 0.1756300192631548, a: <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([-1.07911005])>, b; <tf.Variable 'Variable:0' shape=(1,) dtype=float64, numpy=array([0.93858101])>
